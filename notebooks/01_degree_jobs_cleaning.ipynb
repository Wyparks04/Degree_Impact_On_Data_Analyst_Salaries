# %%
import pandas as pd

degree_jobs = pd.read_csv("../data/ai_jobs_dataset.csv")
degree_jobs.head()
# Out:
#     job_id              job_title  salary_usd salary_currency  \
# 0  AI00001  AI Research Scientist       90376             USD
# 1  AI00002   AI Software Engineer       61895             USD
# 2  AI00003          AI Specialist      152626             USD
# 3  AI00004           NLP Engineer       80215             USD
# 4  AI00005          AI Consultant       54624             EUR
#
#   experience_level employment_type company_location company_size  \
# 0               SE              CT            China            M
# 1               EN              CT           Canada            M
# 2               MI              FL      Switzerland            L
# 3               SE              FL            India            M
# 4               EN              PT           France            S
#
#   employee_residence  remote_ratio  \
# 0              China            50
# 1            Ireland           100
# 2        South Korea             0
# 3              India            50
# ...

# %%
# Find how many Data Analyst jobs are in the job_title column
data_analyst_count = degree_jobs[degree_jobs['job_title'] == 'Data Analyst'].shape[0]
print(f"Number of 'Data Analyst' roles: {data_analyst_count}")
# Out:
# Number of 'Data Analyst' roles: 759

# %%
degree_jobs[degree_jobs['job_title'] == 'Data Analyst'].head(10)
# Out:
#       job_id     job_title  salary_usd salary_currency experience_level  \
# 8    AI00009  Data Analyst      160710             USD               SE
# 27   AI00028  Data Analyst       52997             USD               MI
# 80   AI00081  Data Analyst      157597             EUR               EX
# 91   AI00092  Data Analyst       97997             EUR               SE
# 96   AI00097  Data Analyst      109029             EUR               SE
# 102  AI00103  Data Analyst       91577             EUR               MI
# 117  AI00118  Data Analyst       65570             USD               SE
# 152  AI00153  Data Analyst      184637             USD               EX
# 209  AI00210  Data Analyst       48892             EUR               EN
# 228  AI00229  Data Analyst       52027             USD               MI
#
#     employment_type company_location company_size employee_residence  \
# 8                CT        Singapore            L          Singapore
# ...

# %%
data_analyst_jobs = degree_jobs[degree_jobs['job_title'] == 'Data Analyst']

# %%
data_analyst_jobs.isnull().sum()
# Out:
# job_id                    0
# job_title                 0
# salary_usd                0
# salary_currency           0
# experience_level          0
# employment_type           0
# company_location          0
# company_size              0
# employee_residence        0
# remote_ratio              0
# required_skills           0
# education_required        0
# years_experience          0
# industry                  0
# posting_date              0
# application_deadline      0
# job_description_length    0
# benefits_score            0
# company_name              0
# dtype: int64

# %%
data_analyst_jobs.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 759 entries, 8 to 14982
# Data columns (total 19 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   job_id                  759 non-null    str
#  1   job_title               759 non-null    str
#  2   salary_usd              759 non-null    int64
#  3   salary_currency         759 non-null    str
#  4   experience_level        759 non-null    str
#  5   employment_type         759 non-null    str
#  6   company_location        759 non-null    str
#  7   company_size            759 non-null    str
#  8   employee_residence      759 non-null    str
#  9   remote_ratio            759 non-null    int64
#  10  required_skills         759 non-null    str
#  11  education_required      759 non-null    str
#  12  years_experience        759 non-null    int64
#  13  industry                759 non-null    str
#  14  posting_date            759 non-null    str
# ...

# %%
# Define the columns to keep
columns_to_keep = [
    'job_title', 'salary_usd', 'employment_type', 'company_location', 'remote_ratio',
    'employee_residence', 'required_skills', 'education_required', 'posting_date', 'company_name']

data_analyst_jobs = data_analyst_jobs[columns_to_keep]
data_analyst_jobs.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 759 entries, 8 to 14982
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   job_title           759 non-null    str
#  1   salary_usd          759 non-null    int64
#  2   employment_type     759 non-null    str
#  3   company_location    759 non-null    str
#  4   remote_ratio        759 non-null    int64
#  5   employee_residence  759 non-null    str
#  6   required_skills     759 non-null    str
#  7   education_required  759 non-null    str
#  8   posting_date        759 non-null    str
#  9   company_name        759 non-null    str
# dtypes: int64(2), str(8)
# memory usage: 65.2 KB

# %%
# Renaming columns for consistency
data_analyst_jobs = data_analyst_jobs.rename(columns={
    'remote_ratio': 'is_remote',
    'employee_residence': 'employee_location',
    'required_skills': 'job_skills',
    'education_required': 'degree_type'
})
data_analyst_jobs.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 759 entries, 8 to 14982
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   job_title          759 non-null    str
#  1   salary_usd         759 non-null    int64
#  2   employment_type    759 non-null    str
#  3   company_location   759 non-null    str
#  4   is_remote          759 non-null    int64
#  5   employee_location  759 non-null    str
#  6   job_skills         759 non-null    str
#  7   degree_type        759 non-null    str
#  8   posting_date       759 non-null    str
#  9   company_name       759 non-null    str
# dtypes: int64(2), str(8)
# memory usage: 65.2 KB

# %%
degree_jobs = data_analyst_jobs.copy()

# %%
degree_jobs.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 759 entries, 8 to 14982
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   job_title          759 non-null    str
#  1   salary_usd         759 non-null    int64
#  2   employment_type    759 non-null    str
#  3   company_location   759 non-null    str
#  4   is_remote          759 non-null    int64
#  5   employee_location  759 non-null    str
#  6   job_skills         759 non-null    str
#  7   degree_type        759 non-null    str
#  8   posting_date       759 non-null    str
#  9   company_name       759 non-null    str
# dtypes: int64(2), str(8)
# memory usage: 65.2 KB

# %%
degree_jobs['job_skills'].head()
# Out:
# 8                      Hadoop, Git, Mathematics, Python
# 27    Mathematics, Kubernetes, TensorFlow, Tableau, ...
# 80                 Git, Kubernetes, TensorFlow, R, Java
# 91            Hadoop, Python, TensorFlow, R, Statistics
# 96                              Kubernetes, Scala, Java
# Name: job_skills, dtype: str

# %%
degree_jobs['job_skills'] = degree_jobs['job_skills'].apply(
    lambda x: x if isinstance(x, list) else [skill.strip() for skill in x.split(',')]
)

# %%
# Create indicator columns for each skill of interest
skills_to_track = ['Python', 'SQL', 'Tableau']

for skill in skills_to_track:
    degree_jobs[f"has_{skill.lower()}"] = degree_jobs['job_skills'].apply(
        lambda skills: skill in skills
    )

# %%
degree_jobs.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 759 entries, 8 to 14982
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   job_title          759 non-null    str
#  1   salary_usd         759 non-null    int64
#  2   employment_type    759 non-null    str
#  3   company_location   759 non-null    str
#  4   is_remote          759 non-null    int64
#  5   employee_location  759 non-null    str
#  6   job_skills         759 non-null    object
#  7   degree_type        759 non-null    str
#  8   posting_date       759 non-null    str
#  9   company_name       759 non-null    str
#  10  has_python         759 non-null    bool
#  11  has_sql            759 non-null    bool
#  12  has_tableau        759 non-null    bool
# dtypes: bool(3), int64(2), object(1), str(7)
# memory usage: 67.5+ KB

# %%
# Count skill frequency for python, sql, and tableau
degree_jobs[['has_python', 'has_sql', 'has_tableau',]].sum()
# Out:
# has_python     222
# has_sql        166
# has_tableau    126
# dtype: int64

# %%
# Count individual skills
skills_exploded = degree_jobs['job_skills'].explode()
skills_exploded.value_counts()
# Out:
# job_skills
# Python                222
# Kubernetes            166
# SQL                   166
# Linux                 165
# TensorFlow            160
# Scala                 134
# PyTorch               130
# Git                   128
# Tableau               126
# Hadoop                124
# MLOps                 124
# Java                  123
# GCP                   119
# R                     118
# Data Visualization    116
# Deep Learning         113
# NLP                   112
# Azure                 111
# Docker                110
# Computer Vision       109
# AWS                   104
# Mathematics            97
# Statistics             94
# Spark                  93
# Name: count, dtype: int64

# %%
degree_jobs['company_name'].value_counts()
# Out:
# company_name
# Cloud AI Solutions            67
# Predictive Systems            52
# Cognitive Computing           50
# DataVision Ltd                49
# Neural Networks Co            48
# Algorithmic Solutions         48
# Future Systems                48
# Quantum Computing Inc         47
# TechCorp Inc                  47
# Autonomous Tech               46
# Advanced Robotics             44
# Digital Transformation LLC    43
# DeepTech Ventures             43
# AI Innovations                43
# Smart Analytics               42
# Machine Intelligence Group    42
# Name: count, dtype: int64

# %% [markdown]
# ### Education Requirements and Degree Flag
#
# This dataset includes Data Analyst roles with Associate, Bachelor's, Master's, and PhD education requirements. Because all records in this table represent jobs with a listed degree or formal education requirement, a `degree_flag` value of `1` is assigned to every row.
#
# The `degree_type` column is retained to support later analysis by specific education level.

# %%
degree_jobs['degree_type'].value_counts()
# Out:
# degree_type
# Bachelor     208
# Master       202
# PhD          175
# Associate    174
# Name: count, dtype: int64

# %%
degree_jobs['degree_flag'] = 1
degree_jobs.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 759 entries, 8 to 14982
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   job_title          759 non-null    str
#  1   salary_usd         759 non-null    int64
#  2   employment_type    759 non-null    str
#  3   company_location   759 non-null    str
#  4   is_remote          759 non-null    int64
#  5   employee_location  759 non-null    str
#  6   job_skills         759 non-null    object
#  7   degree_type        759 non-null    str
#  8   posting_date       759 non-null    str
#  9   company_name       759 non-null    str
#  10  has_python         759 non-null    bool
#  11  has_sql            759 non-null    bool
#  12  has_tableau        759 non-null    bool
#  13  degree_flag        759 non-null    int64
# dtypes: bool(3), int64(3), object(1), str(7)
# memory usage: 73.4+ KB

# %%
# Function to put salary into tiers for better visualizations later
def categorize_salary(df: pd.DataFrame, salary_column: str) -> pd.DataFrame:
    """
    Categorizes salaries into income tiers: 'Low', 'Mid', or 'High' based on defined thresholds.

    Args:
        df (pd.DataFrame): The DataFrame containing a salary column as integers.
        salary_column (str): The name of the column with salary values (e.g., 'salary_usd').

    Returns:
        pd.DataFrame: The modified DataFrame with a new 'salary_tier' column.
    """
    bins = [0, 50000, 100000, float('inf')]
    labels = ['Low', 'Mid', 'High']
    df['salary_tier'] = pd.cut(df[salary_column], bins=bins, labels=labels, include_lowest=True)
    return df

# %%
degree_jobs = categorize_salary(degree_jobs, 'salary_usd')
degree_jobs[['salary_usd', 'salary_tier']].head()
# Out:
#     salary_usd salary_tier
# 8       160710        High
# 27       52997         Mid
# 80      157597        High
# 91       97997         Mid
# 96      109029        High

# %%
degree_jobs['is_remote'].unique()
# Out:
# array([  0,  50, 100])

# %%
degree_jobs['is_remote'] = degree_jobs['is_remote'] > 0
print(degree_jobs['is_remote'].head())
# Out:
# 8     False
# 27    False
# 80     True
# 91     True
# 96    False
# Name: is_remote, dtype: bool

# %%
degree_jobs['is_remote'].value_counts()
# Out:
# is_remote
# True     505
# False    254
# Name: count, dtype: int64

# %%
degree_jobs['employee_location'].value_counts()
# Out:
# employee_location
# France            54
# Israel            48
# Austria           46
# Netherlands       45
# Singapore         41
# Ireland           41
# Sweden            40
# Australia         40
# United Kingdom    37
# Germany           37
# Norway            37
# Switzerland       36
# India             36
# Finland           36
# Denmark           35
# United States     34
# South Korea       33
# Japan             31
# China             27
# Canada            25
# Name: count, dtype: int64

# %%
degree_jobs['employment_type'].value_counts()
# Out:
# employment_type
# PT    198
# CT    190
# FT    186
# FL    185
# Name: count, dtype: int64

# %%
degree_jobs['posting_date'].head()
# Out:
# 8     2024-11-04
# 27    2025-01-10
# 80    2024-08-31
# 91    2024-06-19
# 96    2025-04-05
# Name: posting_date, dtype: str

# %%
# Create index and job id column
degree_jobs = degree_jobs.reset_index().rename(columns={'index': 'job_id'})

# %%
# Save cleaned DataFrame to CSV
degree_jobs.to_csv("degree_jobs_cleaned.csv", index=False)
